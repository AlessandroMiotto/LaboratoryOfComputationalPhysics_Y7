# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
numbers = np.random.rand(10)
np.savetxt('simple_data.txt', numbers)

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
matrix = np.random.rand(5,5)
np.savetxt('data.txt', matrix)

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
data_txt = np.loadtxt('data.txt')
# !touch data_txt_to_csv.csv
with open('data_txt_to_csv.csv', 'w') as f:
    for i in range(5):
        for j in range(4):
            f.write(f"{data_txt[i,j]},")
        f.write(f"{data_txt[i, 4]}\n")

#np.loadtxt('data.txt', delimiter=',')

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
with open('credit_card.dat', 'rb') as f:
    for line in f:
        n = int((len(str(int(line)))-4)/6)
        for i in range(n):
            print(chr(int(line[6*i:6*(i+1)],2)), end='')
        print()
# Out:
# 7648 5673 3775 2271
# 3257 8247 3354 2266
# 2722 0001 4011 6652
# 0661 3063 3742 3150
# 0432 1608 1462 4742
# 5827 2027 8785 7303
# 5774 8528 2087 1117
# 8140 1210 6352 2845
# 5764 1133 7301 7100
# 6456 1737 4126 6726
# 1228 8631 7382 0000
# 7051 0160 5374 3166
# 0618 3587 1630 6376
# 1545 5454 7444 5636
# 6735 3116 3202 6834
# 7287 5011 1547 8413
# 7033 2607 3328 4200
# 2568 5244 1874 5024
# 1684 2253 7570 7118
# 0672 2576 0575 6631
# 6332 8353 8787 1340
# 1813 3361 1175 4211
# 2477 6450 8840 2368
# 5512 3505 2563 1326
# 3083 7882 0621 0025
# 4521 5148 8045 0334
# 7563 3654 8713 5787
# 8324 2664 0476 5561
# 0565 2504 7168 3510
# 5107 5507 1767 0738
# 2462 1821 2448 1443
# 2788 0638 6861 6554
# 5851 5873 5474 0547
# 0670 1004 4013 2655
# 5874 5506 3048 0806
# 2805 5401 8462 1260
# 5083 8406 6310 1862
# 1076 1445 3013 2266
# 8440 4804 4844 5277
# 4758 6141 0686 1387
# 7586 0675 0315 2568
# 2544 1258 7432 5165
# 3474 5023 4434 5626
# 1410 0270 0434 5086
# 7315 4446 1104 4215
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json
import numpy as np
json_data = json.load(open('user_data.json'))
ae_data = []
for user in json_data:
    if user['CreditCardType'] == "American Express":
        ae_data.append(user)

with open('ae_data.json', 'w') as f:
    json.dump(ae_data, f)

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
url_1 ='https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1'
data_1 = pd.read_csv(url_1)

# %%
data_1.hist('class')
# Out:
# array([[<Axes: title={'center': 'class'}>]], dtype=object)

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
url_2 ='https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1'
data_2 = pd.read_csv(url_2)
data_2
# Out:
#            label  features_1  features_2  features_3  features_4  features_5  \
# 0     -89.243497    2.175170   -0.285786   -0.603396   -0.627453   -0.686474
# 1     230.050125    1.481941   -1.327870   -0.543583   -0.303578    1.552964
# 2    -286.844411   -1.154394   -0.178649   -1.636646    0.239353   -0.684994
# 3     364.552862    0.197665    1.455707    1.562205    2.168207    0.053335
# 4     515.460006    0.596676    0.969860    1.294158   -0.404728    2.145297
# ...          ...         ...         ...         ...         ...         ...
# 1995 -328.100239   -1.820929    1.358539   -2.494838    0.828299    0.199255
# 1996  -62.960036   -0.883712   -0.063687   -0.418704   -0.872601    0.363769
# 1997  -90.262252   -0.021394   -0.312864   -0.730848   -1.341482   -0.720862
# 1998  -74.333901   -0.041909   -0.862731   -1.232011    1.268843    0.093043
# 1999    8.321454   -1.056364    0.259247    0.307835    1.094903    0.472395
#
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(data_2['features_1'], data_2['features_2'], '.')
plt.xlabel("features_1")
plt.ylabel("features_2")
plt.show()

plt.plot(data_2['features_1'], data_2['features_3'], '.')
plt.xlabel("features_1")
plt.ylabel("features_3")
plt.show()

plt.plot(data_2['features_2'], data_2['features_3'], '.')
plt.xlabel("features_2")
plt.ylabel("features_3")
plt.show()

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
data_1.to_json('out.json')
